# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats # on utilise celui-ci ou scikit-learn ou les deux ?, pour ce tp pas sur que besoin de scikit
import numpy
import seaborn as sns
from sklearn.preprocessing import StandardScaler

sns.set()  # set default graphical style

# Lecture d'un fichier CSV
russia_equip = pd.read_csv(r'C:\Users\samar\OneDrive\Desktop\learning\exchange\ccbda\russia_losses_equipment.csv')

# %%
russia_equip
# Out:
#            date  day  aircraft  helicopter  tank   APC  field artillery  MRL  \
# 0    25/02/2022    2        10           7    80   516               49    4
# 1    26/02/2022    3        27          26   146   706               49    4
# 2    27/02/2022    4        27          26   150   706               50    4
# 3    28/02/2022    5        29          29   150   816               74   21
# 4    01/03/2022    6        29          29   198   846               77   24
# ..          ...  ...       ...         ...   ...   ...              ...  ...
# 433  04/05/2023  435       308         294  3707  7216             2962  547
# 434  05/05/2023  436       308         294  3710  7224             2978  550
# 435  06/05/2023  437       308         294  3717  7238             2992  552
# 436  07/05/2023  438       308         294  3723  7248             3010  554
# 437  08/05/2023  439       308         294  3730  7253             3018  554
#
# ...

# %%
print(russia_equip.info())# displays a summary of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438 entries, 0 to 437
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date                       438 non-null    object
#  1   day                        438 non-null    int64
#  2   aircraft                   438 non-null    int64
#  3   helicopter                 438 non-null    int64
#  4   tank                       438 non-null    int64
#  5   APC                        438 non-null    int64
#  6   field artillery            438 non-null    int64
#  7   MRL                        438 non-null    int64
#  8   military auto              65 non-null     float64
#  9   fuel tank                  65 non-null     float64
#  10  drone                      438 non-null    int64
#  11  naval ship                 438 non-null    int64
#  12  anti-aircraft warfare      438 non-null    int64
# ...

# %%
# for i in range(0, len(df.feature_names)):
#     # check if the YEAR column is not null
#     result =russia_equip.feature_names[i].notnull().all()
#     # print the result
#     print(result)
russia_equip.isnull().sum()
# Out:
# date                           0
# day                            0
# aircraft                       0
# helicopter                     0
# tank                           0
# APC                            0
# field artillery                0
# MRL                            0
# military auto                373
# fuel tank                    373
# drone                          0
# naval ship                     0
# anti-aircraft warfare          0
# special equipment             19
# mobile SRBM system           402
# greatest losses direction    235
# vehicles and fuel tanks       65
# cruise missiles               65
# dtype: int64

# %%
russia_equip['military auto'].fillna(0, inplace=True) # fill in missing values with 0
russia_equip['fuel tank'].fillna(0, inplace=True) # fill in missing values with 0
russia_equip['special equipment'].fillna(0, inplace=True) # fill in missing values with 0
russia_equip['mobile SRBM system'].fillna(0, inplace=True) # fill in missing values with 0
russia_equip['vehicles and fuel tanks'].fillna(0, inplace=True) # fill in missing values with 0
russia_equip['cruise missiles'].fillna(0, inplace=True) # fill in missing values with 0

# %%
import plotly.express as px
fig=px.line(russia_equip,x='date',y=['drone','aircraft','helicopter'],template='ggplot2',title='<b>Russia Air Equipment losses')
fig.show()
names=['aircraft','helicopter','drone']
values=[russia_equip['aircraft'].max(),russia_equip['helicopter'].max(),russia_equip['drone'].max()]
fig=px.pie(names=names,values=values,hole=.7,template='ggplot2')
fig.update_layout(title_x=0.5,legend=dict(orientation='h',yanchor='bottom',y=1.02,xanchor='right',x=1))
# Out:
# <div>                            <div id="735fa882-918e-41f6-a9f1-683976f46ec5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("735fa882-918e-41f6-a9f1-683976f46ec5")) {                    Plotly.newPlot(                        "735fa882-918e-41f6-a9f1-683976f46ec5",                        [{"hovertemplate":"variable=drone<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"drone","line":{"color":"#F8766D","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"drone","showlegend":true,"x":["25/02/2022","26/02/2022","27/02/2022","28/02/2022","01/03/2022","02/03/2022","03/03/2022","04/03/2022","05/03/2022","06/03/2022","07/03/2022","08/03/2022","09/03/2022","10/03/2022","11/03/2022","12/03/2022","13/03/2022","14/03/2022","15/03/2022
# ...

# %%
px.bar(russia_equip.groupby(['greatest losses direction'],as_index=False)[['tank']].count().sort_values(by='tank',ascending=False).reset_index(drop=True).head(15),x='greatest losses direction',y='tank',color='greatest losses direction',text='tank',template='seaborn',labels={'tank':'count'},title='<b>Cities which Reported More Losses ')
# Out:
# <div>                            <div id="f1a9f0ad-6945-4a00-ba6c-d24f87b52e54" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f1a9f0ad-6945-4a00-ba6c-d24f87b52e54")) {                    Plotly.newPlot(                        "f1a9f0ad-6945-4a00-ba6c-d24f87b52e54",                        [{"alignmentgroup":"True","hovertemplate":"greatest losses direction=%{x}<br>count=%{text}<extra></extra>","legendgroup":"Donetsk","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"Donetsk","offsetgroup":"Donetsk","orientation":"v","showlegend":true,"text":[28.0],"textposition":"auto","x":["Donetsk"],"xaxis":"x","y":[28],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"greatest losses direction=%{x}<br>count=%{text}<extra></ext
# ...

# %%
#Data Manipulation, categorizing units based on air, ground, or naval units.
air_units = ['drone','aircraft','helicopter', 'cruise missiles']
naval_units = ['naval ship']
ground_units = ['APC','vehicles and fuel tanks', 'tank', 'field artillery', 'MRL',  'anti-aircraft warfare', 'special equipment']
air_and_naval_units = ['drone','aircraft','helicopter', 'cruise missiles', 'naval ship']

russia_equip['Total Air Units'] = russia_equip[air_units].sum(axis=1)
russia_equip['Total Naval Units'] = russia_equip[naval_units].sum(axis=1)
russia_equip['Total Ground Units'] = russia_equip[ground_units].sum(axis=1)
russia_equip.head()
# Out:
#          date  day  aircraft  helicopter  tank  APC  field artillery  MRL  \
# 0  25/02/2022    2        10           7    80  516               49    4
# 1  26/02/2022    3        27          26   146  706               49    4
# 2  27/02/2022    4        27          26   150  706               50    4
# 3  28/02/2022    5        29          29   150  816               74   21
# 4  01/03/2022    6        29          29   198  846               77   24
#
#    military auto  fuel tank  ...  naval ship  anti-aircraft warfare  \
# 0          100.0       60.0  ...           2                      0
# 1          130.0       60.0  ...           2                      0
# 2          130.0       60.0  ...           2                      0
# 3          291.0       60.0  ...           2                      5
# 4          305.0       60.0  ...           2                      7
#
#    special equipment  mobile SRBM system  greatest losses direction  \
# ...

# %%
russia_equip.to_csv(r'C:\Users\samar\OneDrive\Desktop\learning\exchange\ccbda\cleaned_data_equip.csv', index=False)
