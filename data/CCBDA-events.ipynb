# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats # on utilise celui-ci ou scikit-learn ou les deux ?, pour ce tp pas sur que besoin de scikit
import numpy
import seaborn as sns
from sklearn.preprocessing import StandardScaler

sns.set()  # set default graphical style

# Lecture d'un fichier CSV
ukrain = pd.read_excel(r'C:\Users\samar\OneDrive\Desktop\learning\exchange\ccbda\Ukraine_Black_Sea_2020_2023_Apr28-1.xlsx')

# %%
ukrain
# Out:
#        EVENT_ID_CNTY EVENT_DATE  YEAR  TIME_PRECISION           DISORDER_TYPE  \
# 0             ROU448 2019-05-20  2019               1      Political violence
# 1            ROU1885 2022-03-28  2022               1  Strategic developments
# 2            ROU1940 2022-07-28  2022               1          Demonstrations
# 3            ROU1945 2022-07-31  2022               1  Strategic developments
# 4            ROU1947 2022-08-04  2022               1          Demonstrations
# ...              ...        ...   ...             ...                     ...
# 101203     UKR101630 2023-04-28  2023               1      Political violence
# 101204     UKR101631 2023-04-28  2023               1      Political violence
# 101205     UKR101632 2023-04-28  2023               1      Political violence
# 101206     UKR101633 2023-04-28  2023               1      Political violence
# 101207     UKR101634 2023-04-28  2023               1      Political violence
#
# ...

# %%
#extract date,location with latitude and longitude, event type, deaths+injuries

# %%
print(ukrain.info())# displays a summary of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101208 entries, 0 to 101207
# Data columns (total 31 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   EVENT_ID_CNTY       101208 non-null  object
#  1   EVENT_DATE          101208 non-null  datetime64[ns]
#  2   YEAR                101208 non-null  int64
#  3   TIME_PRECISION      101208 non-null  int64
#  4   DISORDER_TYPE       101208 non-null  object
#  5   EVENT_TYPE          101208 non-null  object
#  6   SUB_EVENT_TYPE      101208 non-null  object
#  7   ACTOR1              101208 non-null  object
#  8   ASSOC_ACTOR_1       6789 non-null    object
#  9   INTER1              101208 non-null  int64
#  10  ACTOR2              54086 non-null   object
#  11  ASSOC_ACTOR_2       14938 non-null   object
#  12  INTER2              101208 non-null  int64
#  13  INTERACTION         101208 non-null  int64
#  14  CIVILIAN_TARGETING  4467 non-null    object
# ...

# %%
print(ukrain.describe()) # displays summary statistics for numerical columns
# Out:
#                 YEAR  TIME_PRECISION         INTER1         INTER2  \
# count  101208.000000   101208.000000  101208.000000  101208.000000
# mean     2020.771945        1.011926       4.275255       1.353806
# std         1.728534        0.123299       3.200034       2.142006
# min      2018.000000        1.000000       1.000000       0.000000
# 25%      2019.000000        1.000000       1.000000       0.000000
# 50%      2022.000000        1.000000       2.000000       1.000000
# 75%      2022.000000        1.000000       8.000000       2.000000
# max      2023.000000        3.000000       8.000000       8.000000
#
#          INTERACTION            ISO       LATITUDE      LONGITUDE  \
# count  101208.000000  101208.000000  101208.000000  101208.000000
# mean       36.603065     803.986365      48.384072      36.698884
# std        30.501452       1.443695       1.100528       2.544473
# min        10.000000     642.000000      41.162000      22.163000
# ...

# %%
print(ukrain.isnull()) # displays a Boolean value (True or False) for each cell in the dataset
# Out:
#         EVENT_ID_CNTY  EVENT_DATE   YEAR  TIME_PRECISION  DISORDER_TYPE  \
# 0               False       False  False           False          False
# 1               False       False  False           False          False
# 2               False       False  False           False          False
# 3               False       False  False           False          False
# 4               False       False  False           False          False
# ...               ...         ...    ...             ...            ...
# 101203          False       False  False           False          False
# 101204          False       False  False           False          False
# 101205          False       False  False           False          False
# 101206          False       False  False           False          False
# 101207          False       False  False           False          False
#
#         EVENT_TYPE  SUB_EVENT_TYPE  ACTOR1  ASSOC_ACTOR_1  INTER1  ...  \
# ...

# %%
# check if the YEAR column is not null
assert ukrain['YEAR'].notnull().all()# raises an error if any value in the column is missing

# %%
assert ukrain['LATITUDE'].notnull().all()

# %%
assert ukrain['LONGITUDE'].notnull().all()

# %%
assert ukrain['EVENT_TYPE'].notnull().all()

# %%
assert ukrain['EVENT_DATE'].notnull().all()

# %%
# check if the YEAR column is not null
result = ukrain['YEAR'].notnull().all()

# print the result
print(result)
# Out:
# True

# %%
#ukrain['column_name'].fillna(0, inplace=True) # fill in missing values with 0

# %%
#ukrain.dropna(inplace=True) # removes all rows with missing values

# %%
# show the unique values in the YEAR column
unique_years = ukrain['YEAR'].unique()
print(unique_years)
# Out:
# [2019 2022 2023 2020 2021 2018]

# %%
# show the unique values in the YEAR column
unique_event = ukrain['EVENT_TYPE'].unique()
print(unique_event)
# Out:
# ['Violence against civilians' 'Strategic developments' 'Protests'
#  'Explosions/Remote violence' 'Battles' 'Riots']

# %%
ukrain['EVENT_TYPE'].replace('Protests', 'P', inplace=True)
ukrain['EVENT_TYPE'].replace('Violence against civilians', 'V', inplace=True)
ukrain['EVENT_TYPE'].replace('Explosions/Remote violence', 'E', inplace=True)
ukrain['EVENT_TYPE'].replace('Battles', 'B', inplace=True)
ukrain['EVENT_TYPE'].replace('Riots', 'R', inplace=True)
ukrain['EVENT_TYPE'].replace('Strategic developments', 'S', inplace=True)

# %%
ukrain['EVENT_TYPE']
# Out:
# 0         V
# 1         S
# 2         P
# 3         S
# 4         P
#          ..
# 101203    E
# 101204    E
# 101205    E
# 101206    E
# 101207    E
# Name: EVENT_TYPE, Length: 101208, dtype: object

# %%
#ukrain.drop_duplicates(subset=['column_1', 'column_2'], inplace=True)

# %%
Ukrain1 = pd.DataFrame();
Ukrain1['LATITUDE']=ukrain['LATITUDE']
Ukrain1['LONGITUDE']=ukrain['LONGITUDE']
Ukrain1['EVENT_DATE']=ukrain['EVENT_DATE']
Ukrain1['EVENT_TYPE']=ukrain['EVENT_TYPE']

# %%
Ukrain1
# Out:
#         LATITUDE  LONGITUDE EVENT_DATE EVENT_TYPE
# 0         44.156     28.948 2019-05-20          V
# 1         44.156     28.948 2022-03-28          S
# 2         44.156     28.948 2022-07-28          P
# 3         44.156     28.948 2022-07-31          S
# 4         44.156     28.948 2022-08-04          P
# ...          ...        ...        ...        ...
# 101203    48.130     37.859 2023-04-28          E
# 101204    47.707     37.225 2023-04-28          E
# 101205    47.645     36.170 2023-04-28          E
# 101206    49.822     37.614 2023-04-28          E
# 101207    47.685     36.328 2023-04-28          E
#
# [101208 rows x 4 columns]

# %%
Ukrain1.to_csv(r'C:\Users\samar\OneDrive\Desktop\learning\exchange\ccbda\cleaned_data_events.csv', index=False)
